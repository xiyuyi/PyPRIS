# %% [markdown]
# # stitch 4 field of views together.

# %%
# load modules
import sys
sys.path.append("../")
from PyPRIS import *
import os

# %%
oxs = [1165-41, 1155-41, 1143-41, 1132-41 ] 
oys = [1369-41, 1392-41, 1412-41, 1432-41 ]

# %%
# define boundaries for ox and oy:
x_boundaries = [[ np.inf, 1160],   [1161,   1149], [1150, 1137.5], [1137.5+1, -np.inf]]
y_boundaries = [[-np.inf, 1380.5+1], [1380.5, 1402+1],  [1402, 1422+1],   [1422,    np.inf]]

x_boundaries = [[ np.inf, 1160],   [1161,   1149], [1150, 1123], [0, 0]]
y_boundaries = [[-np.inf, 1380.5+1], [1380.5, 1402+1],  [1402, 1428],   [0,0]]


#x_boundaries = [[ np.inf, -np.inf], [ np.inf, -np.inf],[ np.inf, -np.inf],[ np.inf, -np.inf]]
#y_boundaries = [[-np.inf,  np.inf], [-np.inf,  np.inf], [-np.inf,  np.inf], [-np.inf,  np.inf]]

# %%
# prepare datafile paths.


datapath_key_minimum_seed="./Documents/Data_key_minimum_seed"
for prisN in np.arange(0,8):
    exec("pris"+str(prisN)+"_names = list()")
    exec("pris"+str(prisN)+"_linbregs = list()")
    exec("pris"+str(prisN)+"_pyprises = list()")

# define the names of the linbreg objects for each pris iteration on fov1.
pris0_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris0_7001.file")
pris1_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris1_34520.file")
pris2_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris2_40000.file")
pris3_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris3_40000.file")
pris4_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris4_40000.file")
pris5_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris5_40000.file")
pris6_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris6_40000.file")
pris7_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris7_40000.file")

# define the names of the linbreg objects for each pris iteration on fov2.
pris0_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris0_4028.file")
pris1_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris1_40000.file")
pris2_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris2_40000.file")
pris3_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris3_40000.file")
pris4_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris4_40000.file")
pris5_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris5_40000.file")
pris6_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris6_40000.file")
pris7_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris7_8879.file")

# define the names of the linbreg objects for each pris iteration on fov3.
pris0_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris0_1696.file")
pris1_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris1_40000.file")
pris2_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris2_40000.file")
pris3_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris3_40000.file")
pris4_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris4_40000.file")
pris5_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris5_40000.file")
pris6_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris6_40000.file")
pris7_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris7_40000.file")

# define the names of the linbreg objects for each pris iteration on fov4.
pris0_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris0_1330.file")
pris1_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris1_25573.file")
pris2_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris2_40000.file")
pris3_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris3_40000.file")
pris4_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris4_40000.file")
pris5_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris5_40000.file")
pris6_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris6_40000.file")
pris7_names.append("PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris7_17227.file")

for Ind in np.arange(0, 4):
    pris0_linbregs.append(datapath_key_minimum_seed + "/Feature3/fov" + str(Ind + 1) + "/" + pris0_names[Ind])
    pris1_linbregs.append(datapath_key_minimum_seed + "/Feature3/fov" + str(Ind + 1) + "/" + pris1_names[Ind])
    pris2_linbregs.append(datapath_key_minimum_seed + "/Feature3/fov" + str(Ind + 1) + "/" + pris2_names[Ind])
    pris3_linbregs.append(datapath_key_minimum_seed + "/Feature3/fov" + str(Ind + 1) + "/" + pris3_names[Ind])
    pris4_linbregs.append(datapath_key_minimum_seed + "/Feature3/fov" + str(Ind + 1) + "/" + pris4_names[Ind])
    pris5_linbregs.append(datapath_key_minimum_seed + "/Feature3/fov" + str(Ind + 1) + "/" + pris5_names[Ind])
    pris6_linbregs.append(datapath_key_minimum_seed + "/Feature3/fov" + str(Ind + 1) + "/" + pris6_names[Ind])
    pris7_linbregs.append(datapath_key_minimum_seed + "/Feature3/fov" + str(Ind + 1) + "/" + pris7_names[Ind])

# %% [markdown]
# ## check pris0

# %%
lb_all = LinBreg('All')
vis_list = list()

x = list()
for lb_path, ox, oy, xbounds, ybounds in zip(pris0_linbregs, oxs, oys, x_boundaries, y_boundaries):
    with open(lb_path,'rb') as f:
        lb = pickle.load(f)
        vis_list.append(lb.candidate_vis())
    
    xs = list(lb.x[0:-1]) 
    for ind, coord in enumerate(lb.candidate_coords):
        coordx = coord[1] + ox
        coordy = coord[2] + oy
        if coordx > xbounds[0]: xs[ind] = 0.0  
        if coordx <  xbounds[1]: xs[ind] = 0.0
        #if coordy <  ybounds[0]: xs[ind] = 0.0
        #if coordy > ybounds[1]: xs[ind] = 0.0
            
    for ele in lb.candidate_coords:   
        lb_all.candidate_coords.append([ele[0],ele[1]+ox,ele[2]+oy])
    
    print(len(lb.x))
    for ele in xs:
        x.append(ele)       

lb_all.candidate_intervals = lb.candidate_intervals
lb_all.x = np.asarray(x)

vis = lb_all.candidate_vis()
plt.figure(figsize=(15,15))
plt.subplot(241)
plt.imshow(np.mean(vis_list[0],axis=0))
plt.subplot(242)
plt.imshow(np.mean(vis_list[1],axis=0))
plt.subplot(243)
plt.imshow(np.mean(vis_list[2],axis=0))
plt.subplot(244)
plt.imshow(np.mean(vis_list[3],axis=0))

plt.figure(figsize=(10,10))

plt.subplot(245)
plt.imshow(np.mean(vis,axis=0))
plt.subplot(246)
plt.imshow(np.mean(vis,axis=0),vmin=0, vmax=0.03)
plt.figure(figsize=(10,10))
plt.imshow(np.mean(vis,axis=0),vmin=0, vmax=0.00001)
plt.figure(figsize=(10,10))
plt.imshow(np.mean(vis,axis=0))
# Out:
# 11761
# 11761
# 11761
# 11761

# %%
lb_all = LinBreg('All')
vis_list = list()

x = list()
for lb_path, ox, oy, xbounds, ybounds in zip(pris1_linbregs, oxs, oys, x_boundaries, y_boundaries):
    with open(lb_path,'rb') as f:
        lb = pickle.load(f)
        vis_list.append(lb.candidate_vis())
    
    xs = list(lb.x[0:-1]) 
    for ind, coord in enumerate(lb.candidate_coords):
        coordx = coord[1] + ox
        coordy = coord[2] + oy
        if coordx >= xbounds[0]: xs[ind] = 0.0  
        if coordx <  xbounds[1]: xs[ind] = 0.0
        #if coordy <  ybounds[0]: xs[ind] = 0.0
        #if coordy >= ybounds[1]: xs[ind] = 0.0
            
    for ele in lb.candidate_coords:   
        lb_all.candidate_coords.append([ele[0],ele[1]+ox,ele[2]+oy])
    
    print(len(lb.x))
    for ele in xs:
        x.append(ele)       

lb_all.candidate_intervals = lb.candidate_intervals
lb_all.x = np.asarray(x)

vis = lb_all.candidate_vis()
plt.figure(figsize=(15,15))
plt.subplot(241)
plt.imshow(np.mean(vis_list[0],axis=0))
plt.subplot(242)
plt.imshow(np.mean(vis_list[1],axis=0))
plt.subplot(243)
plt.imshow(np.mean(vis_list[2],axis=0))
plt.subplot(244)
plt.imshow(np.mean(vis_list[3],axis=0))

plt.figure(figsize=(10,10))

plt.subplot(245)
plt.imshow(np.mean(vis,axis=0))
plt.subplot(246)
plt.imshow(np.mean(vis,axis=0),vmin=0, vmax=0.03)
plt.figure(figsize=(10,10))
plt.imshow(np.mean(vis,axis=0),vmin=0, vmax=0.00001)
plt.figure(figsize=(10,10))
plt.imshow(np.mean(vis,axis=0))
# Out:
# 3313
# 3965
# 5173
# 6601

# %%
lb_all = LinBreg('All')
vis_list = list()

x = list()
for lb_path, ox, oy, xbounds, ybounds in zip(pris2_linbregs, oxs, oys, x_boundaries, y_boundaries):
    with open(lb_path,'rb') as f:
        lb = pickle.load(f)
        vis_list.append(lb.candidate_vis())
    
    xs = list(lb.x[0:-1]) 
    for ind, coord in enumerate(lb.candidate_coords):
        coordx = coord[1] + ox
        coordy = coord[2] + oy
        if coordx >= xbounds[0]: xs[ind] = 0.0  
        if coordx <  xbounds[1]: xs[ind] = 0.0
        #if coordy <  ybounds[0]: xs[ind] = 0.0
        #if coordy >= ybounds[1]: xs[ind] = 0.0
            
    for ele in lb.candidate_coords:   
        lb_all.candidate_coords.append([ele[0],ele[1]+ox,ele[2]+oy])
    
    print(len(lb.x))
    for ele in xs:
        x.append(ele)       

lb_all.candidate_intervals = lb.candidate_intervals
lb_all.x = np.asarray(x)

vis = lb_all.candidate_vis()
plt.figure(figsize=(15,15))
plt.subplot(241)
plt.imshow(np.mean(vis_list[0],axis=0))
plt.subplot(242)
plt.imshow(np.mean(vis_list[1],axis=0))
plt.subplot(243)
plt.imshow(np.mean(vis_list[2],axis=0))
plt.subplot(244)
plt.imshow(np.mean(vis_list[3],axis=0))

plt.figure(figsize=(10,10))

plt.subplot(245)
plt.imshow(np.mean(vis,axis=0))
plt.subplot(246)
plt.imshow(np.mean(vis,axis=0),vmin=0, vmax=0.03)
plt.figure(figsize=(10,10))
plt.imshow(np.mean(vis,axis=0),vmin=0, vmax=0.00001)
plt.figure(figsize=(10,10))
plt.imshow(np.mean(vis,axis=0))
# Out:
# 4229
# 4173
# 4041
# 5169

# %%
lb_all = LinBreg('All')
vis_list = list()

x = list()
for lb_path, ox, oy, xbounds, ybounds in zip(pris3_linbregs, oxs, oys, x_boundaries, y_boundaries):
    with open(lb_path,'rb') as f:
        lb = pickle.load(f)
        vis_list.append(lb.candidate_vis())
    
    xs = list(lb.x[0:-1]) 
    for ind, coord in enumerate(lb.candidate_coords):
        coordx = coord[1] + ox
        coordy = coord[2] + oy
        #if coordx >= xbounds[0]: xs[ind] = 0.0  
        #if coordx <  xbounds[1]: xs[ind] = 0.0
        #if coordy <  ybounds[0]: xs[ind] = 0.0
        #if coordy > ybounds[1]: xs[ind] = 0.0
            
    for ele in lb.candidate_coords:   
        lb_all.candidate_coords.append([ele[0],ele[1]+ox,ele[2]+oy])
    
    print(len(lb.x))
    for ele in xs:
        x.append(ele)       

lb_all.candidate_intervals = lb.candidate_intervals
lb_all.x = np.asarray(x)

vis = lb_all.candidate_vis()
plt.figure(figsize=(15,15))
plt.subplot(241)
plt.imshow(np.mean(vis_list[0],axis=0))
plt.subplot(242)
plt.imshow(np.mean(vis_list[1],axis=0))
plt.subplot(243)
plt.imshow(np.mean(vis_list[2],axis=0))
plt.subplot(244)
plt.imshow(np.mean(vis_list[3],axis=0))

plt.figure(figsize=(10,10))

plt.subplot(245)
plt.imshow(np.mean(vis,axis=0))
plt.subplot(246)
plt.imshow(np.mean(vis,axis=0),vmin=0, vmax=0.03)
plt.figure(figsize=(10,10))
plt.imshow(np.mean(vis,axis=0),vmin=0, vmax=0.00001)
plt.figure(figsize=(10,10))
plt.imshow(np.mean(vis,axis=0))


prj_ax0 = copy.deepcopy(np.mean(vis, axis=0))
prj_ax1 = copy.deepcopy(np.mean(vis, axis=1))
prj_ax2 = copy.deepcopy(np.mean(vis, axis=2).T)
patch = np.zeros((vis.shape[0],vis.shape[0]))
cat1 = np.concatenate([prj_ax0, prj_ax2], axis = 1)
cat2 = np.concatenate([prj_ax1, patch], axis = 1)
cat = np.concatenate([cat1, cat2], axis = 0)
plt.figure(figsize=(3,3))
plt.imshow(cat)
plt.savefig(
    '../PyPRIS_pris3.png',
    dpi=300, figsize=(100, 80))

plt.figure(figsize=(3,3))
plt.imshow(cat,vmin=0,vmax=0.004)
plt.savefig(
    '../PyPRIS_pris3_sat.png',
    dpi=300, figsize=(100, 80))
# Out:
# 6445
# 5877
# 6077
# 7585

# %%
lb_all = LinBreg('All')
vis_list = list()

x = list()
for lb_path, ox, oy, xbounds, ybounds in zip(pris4_linbregs, oxs, oys, x_boundaries, y_boundaries):
    with open(lb_path,'rb') as f:
        lb = pickle.load(f)
        vis_list.append(lb.candidate_vis())
    
    xs = list(lb.x[0:-1]) 
    for ind, coord in enumerate(lb.candidate_coords):
        coordx = coord[1] + ox
        coordy = coord[2] + oy
        if coordx >= xbounds[0]: xs[ind] = 0.0  
        if coordx <  xbounds[1]: xs[ind] = 0.0
        #if coordy <  ybounds[0]: xs[ind] = 0.0
        #if coordy >= ybounds[1]: xs[ind] = 0.0
            
    for ele in lb.candidate_coords:   
        lb_all.candidate_coords.append([ele[0],ele[1]+ox,ele[2]+oy])
    
    print(len(lb.x))
    for ele in xs:
        x.append(ele)       

lb_all.candidate_intervals = lb.candidate_intervals
lb_all.x = np.asarray(x)

vis = lb_all.candidate_vis()
plt.figure(figsize=(15,15))
plt.subplot(241)
plt.imshow(np.mean(vis_list[0],axis=0))
plt.subplot(242)
plt.imshow(np.mean(vis_list[1],axis=0))
plt.subplot(243)
plt.imshow(np.mean(vis_list[2],axis=0))
plt.subplot(244)
plt.imshow(np.mean(vis_list[3],axis=0))

plt.figure(figsize=(10,10))

plt.subplot(245)
plt.imshow(np.mean(vis,axis=0))
plt.subplot(246)
plt.imshow(np.mean(vis,axis=0),vmin=0, vmax=0.03)
plt.figure(figsize=(10,10))
plt.imshow(np.mean(vis,axis=0),vmin=0, vmax=0.00001)
plt.figure(figsize=(10,10))
plt.imshow(np.mean(vis,axis=0))




prj_ax0 = copy.deepcopy(np.mean(vis, axis=0))
prj_ax1 = copy.deepcopy(np.mean(vis, axis=1))
prj_ax2 = copy.deepcopy(np.mean(vis, axis=2).T)
patch = np.zeros((vis.shape[0],vis.shape[0]))
cat1 = np.concatenate([prj_ax0, prj_ax2], axis = 1)
cat2 = np.concatenate([prj_ax1, patch], axis = 1)
cat = np.concatenate([cat1, cat2], axis = 0)
plt.figure(figsize=(13,13))
plt.imshow(cat,cmap='gray')
plt.savefig(
    '../PyPRIS_pris4.png',
    dpi=300, figsize=(100, 80))

plt.figure(figsize=(13,13))
plt.imshow(cat,vmin=0,vmax=0.001,cmap='gray')
plt.savefig(
    '../PyPRIS_pris4_sat.png',
    dpi=300, figsize=(100, 80))
# Out:
# 10673
# 9997
# 10409
# 12825

# %%
lb_all = LinBreg('All')
vis_list = list()

x = list()
for lb_path, ox, oy, xbounds, ybounds in zip(pris5_linbregs, oxs, oys, x_boundaries, y_boundaries):
    print(lb_path)
    with open(lb_path,'rb') as f:
        lb = pickle.load(f)
        vis_list.append(lb.candidate_vis())
    
    xs = list(lb.x[0:-1]) 
    for ind, coord in enumerate(lb.candidate_coords):
        coordx = coord[1] + ox
        coordy = coord[2] + oy
        if coordx > xbounds[0]: xs[ind] = 0.0  
        if coordx <  xbounds[1]: xs[ind] = 0.0
        #if coordy <  ybounds[0]: xs[ind] = 0.0
        #if coordy >= ybounds[1]: xs[ind] = 0.0
            
    for ele in lb.candidate_coords:   
        lb_all.candidate_coords.append([ele[0],ele[1]+ox,ele[2]+oy])
    
    print(len(lb.x))
    for ele in xs:
        x.append(ele)       

lb_all.candidate_intervals = lb.candidate_intervals
lb_all.x = np.asarray(x)

vis = lb_all.candidate_vis()
plt.figure(figsize=(15,15))
plt.subplot(241)
plt.imshow(np.mean(vis_list[0],axis=0))
plt.subplot(242)
plt.imshow(np.mean(vis_list[1],axis=0))
plt.subplot(243)
plt.imshow(np.mean(vis_list[2],axis=0))
plt.subplot(244)
plt.imshow(np.mean(vis_list[3],axis=0))

plt.figure(figsize=(10,10))

plt.subplot(245)
plt.imshow(np.mean(vis,axis=0))
plt.subplot(246)
plt.imshow(np.mean(vis,axis=0),vmin=0, vmax=0.03)
plt.figure(figsize=(10,10))
plt.imshow(np.mean(vis,axis=0),vmin=0, vmax=0.00001)
plt.figure(figsize=(10,10))
plt.imshow(np.mean(vis,axis=0))

prj_ax0 = copy.deepcopy(np.mean(vis, axis=0))
prj_ax1 = copy.deepcopy(np.mean(vis, axis=1))
prj_ax2 = copy.deepcopy(np.mean(vis, axis=2).T)
patch = np.zeros((vis.shape[0],vis.shape[0]))
cat1 = np.concatenate([prj_ax0, prj_ax2], axis = 1)
cat2 = np.concatenate([prj_ax1, patch], axis = 1)
cat = np.concatenate([cat1, cat2], axis = 0)
plt.figure(figsize=(3,3))
plt.imshow(cat)
plt.savefig(
    '../PyPRIS_pris5.png',
    dpi=300, figsize=(100, 80))

plt.figure(figsize=(13,13))
plt.imshow(cat,vmin=0,vmax=0.001,cmap='gray')
plt.savefig(
    '../PyPRIS_pris5_sat.png',
    dpi=300, figsize=(100, 80),cmap='gray')
# Out:
# ./Documents/Data_key_minimum_seed/Feature3/fov1/PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris5_40000.file
# 17613
# ./Documents/Data_key_minimum_seed/Feature3/fov2/PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris5_40000.file
# 16661
# ./Documents/Data_key_minimum_seed/Feature3/fov3/PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris5_40000.file
# 17701
# ./Documents/Data_key_minimum_seed/Feature3/fov4/PyPRIS_bgSCF2_mu1.0e+04_alpha1.0e-09_pris5_40000.file
# 22881

# %%
lb_all = LinBreg('All')
vis_list = list()

x = list()
for lb_path, ox, oy, xbounds, ybounds in zip(pris6_linbregs, oxs, oys, x_boundaries, y_boundaries):
    with open(lb_path,'rb') as f:
        lb = pickle.load(f)
        vis_list.append(lb.candidate_vis())
    
    xs = list(lb.x[0:-1]) 
    for ind, coord in enumerate(lb.candidate_coords):
        coordx = coord[1] + ox
        coordy = coord[2] + oy
        if coordx >= xbounds[0]: xs[ind] = 0.0  
        if coordx <  xbounds[1]: xs[ind] = 0.0
        #if coordy <  ybounds[0]: xs[ind] = 0.0
        #if coordy >= ybounds[1]: xs[ind] = 0.0
            
    for ele in lb.candidate_coords:   
        lb_all.candidate_coords.append([ele[0],ele[1]+ox,ele[2]+oy])
    
    print(len(lb.x))
    for ele in xs:
        x.append(ele)       

lb_all.candidate_intervals = lb.candidate_intervals
lb_all.x = np.asarray(x)

vis = lb_all.candidate_vis()
plt.figure(figsize=(15,15))
plt.subplot(241)
plt.imshow(np.mean(vis_list[0],axis=0))
plt.subplot(242)
plt.imshow(np.mean(vis_list[1],axis=0))
plt.subplot(243)
plt.imshow(np.mean(vis_list[2],axis=0))
plt.subplot(244)
plt.imshow(np.mean(vis_list[3],axis=0))

plt.figure(figsize=(10,10))

plt.subplot(245)
plt.imshow(np.mean(vis,axis=0))
plt.subplot(246)
plt.imshow(np.mean(vis,axis=0),vmin=0, vmax=0.03)
plt.figure(figsize=(10,10))
plt.imshow(np.mean(vis,axis=0),vmin=0, vmax=0.00001)
plt.figure(figsize=(10,10))
plt.imshow(np.mean(vis,axis=0))

prj_ax0 = copy.deepcopy(np.mean(vis, axis=0))
prj_ax1 = copy.deepcopy(np.mean(vis, axis=1))
prj_ax2 = copy.deepcopy(np.mean(vis, axis=2).T)
patch = np.zeros((vis.shape[0],vis.shape[0]))
cat1 = np.concatenate([prj_ax0, prj_ax2], axis = 1)
cat2 = np.concatenate([prj_ax1, patch], axis = 1)
cat = np.concatenate([cat1, cat2], axis = 0)
plt.figure(figsize=(3,3))
plt.imshow(cat)
plt.savefig(
    '../PyPRIS_pris6.png',
    dpi=300, figsize=(100, 80))

plt.figure(figsize=(3,3))
plt.imshow(cat,vmin=0,vmax=0.0001)
plt.savefig(
    '../PyPRIS_pris6_sat.png',
    dpi=300, figsize=(100, 80))
# Out:
# 30677
# 27801
# 30133
# 39449

# %%
lb_all = LinBreg('All')
vis_list = list()

x = list()
for lb_path, ox, oy, xbounds, ybounds in zip(pris7_linbregs, oxs, oys, x_boundaries, y_boundaries):
    with open(lb_path,'rb') as f:
        lb = pickle.load(f)
        vis_list.append(lb.candidate_vis())
    
    xs = list(lb.x[0:-1]) 
    for ind, coord in enumerate(lb.candidate_coords):
        coordx = coord[1] + ox
        coordy = coord[2] + oy
        if coordx >= xbounds[0]: xs[ind] = 0.0  
        if coordx <  xbounds[1]: xs[ind] = 0.0
        #if coordy <  ybounds[0]: xs[ind] = 0.0
        #if coordy >= ybounds[1]: xs[ind] = 0.0
            
    for ele in lb.candidate_coords:   
        lb_all.candidate_coords.append([ele[0],ele[1]+ox,ele[2]+oy])
    
    print(len(lb.x))
    for ele in xs:
        x.append(ele)       

lb_all.candidate_intervals = lb.candidate_intervals
lb_all.x = np.asarray(x)

vis = lb_all.candidate_vis()
plt.figure(figsize=(15,15))
plt.subplot(241)
plt.imshow(np.mean(vis_list[0],axis=0))
plt.subplot(242)
plt.imshow(np.mean(vis_list[1],axis=0))
plt.subplot(243)
plt.imshow(np.mean(vis_list[2],axis=0))
plt.subplot(244)
plt.imshow(np.mean(vis_list[3],axis=0))

plt.figure(figsize=(10,10))

plt.subplot(245)
plt.imshow(np.mean(vis,axis=0))
plt.subplot(246)
plt.imshow(np.mean(vis,axis=0),vmin=0, vmax=0.03)
plt.figure(figsize=(10,10))
plt.imshow(np.mean(vis,axis=0),vmin=0, vmax=0.00001)
plt.figure(figsize=(10,10))
plt.imshow(np.mean(vis,axis=0))
# Out:
# 52861
# 49629
# 54101
# 67465

# %% [markdown]
# # Produce figures for publication

# %%
prisN_list = list(np.arange(0,8))
pris_linbregs_list = list()
for prisN in prisN_list:
    exec("pris_linbregs_list.append(pris"+str(prisN)+"_linbregs)")

# %% [markdown]
# ## organize linbreg results for all fov and all prisN

# %%
psize = 62.7579 # pixel size is 62.7579 nanometers as measured by a reticle.
prj0_list = list()
prj1_list = list()
prj2_list = list()
interv_list = list()
for prisN, pris_linbregs in zip(prisN_list, pris_linbregs_list):
    print("now check pris"+str(prisN))
    lb_all = LinBreg('All')
    vis_list = list()
    x = list()
    for lb_path, ox, oy, xbounds, ybounds in zip(pris_linbregs, oxs, oys, x_boundaries, y_boundaries):
        with open(lb_path,'rb') as f:
            lb = pickle.load(f)
            vis_list.append(lb.candidate_vis())

        xs = list(lb.x[0:-1]) 
        for ind, coord in enumerate(lb.candidate_coords):
            coordx = coord[1] + ox
            coordy = coord[2] + oy
            if coordx > xbounds[0]: xs[ind] = 0.0  
            if coordx <  xbounds[1]: xs[ind] = 0.0
            #if coordy <  ybounds[0]: xs[ind] = 0.0
            #if coordy > ybounds[1]: xs[ind] = 0.0

        for ele in lb.candidate_coords:   
            lb_all.candidate_coords.append([ele[0],ele[1]+ox,ele[2]+oy])

        print("total number of candidates: " + str(len(lb.x)))
        for ele in xs:
            x.append(ele)       

    lb_all.candidate_intervals = lb.candidate_intervals
    # now add the 8 corner zeros for the field of view alingment 
    #xpeak = np.max(x[0:-1])
    for corner_z in [31,-41]:
        for corner_x in [1237, 1063]:
            for corner_y in [1294, 1504]:
                lb_all.candidate_coords.append([corner_z, corner_x, corner_y])
                x.append(0)
                
    lb_all.x = np.asarray(x)
    vis = lb_all.candidate_vis()
    prj_ax0 = copy.deepcopy(np.mean(vis, axis=0))
    prj_ax1 = copy.deepcopy(np.mean(vis, axis=1))
    prj_ax2 = copy.deepcopy(np.mean(vis, axis=2).T)
    patch = np.zeros((vis.shape[0],vis.shape[0]))
    cat1 = np.concatenate([prj_ax0, prj_ax2], axis = 1)
    cat2 = np.concatenate([prj_ax1, patch], axis = 1)
    cat = np.concatenate([cat1, cat2], axis = 0)
    plt.figure(figsize=(13,13))
    plt.imshow(cat,cmap='gray')
    plt.savefig(
        '../PyPRIS_pris'+str(prisN)+'.png',
        dpi=300, figsize=(100, 80))
    plt.close()
    plt.figure(figsize=(13,13))
    plt.imshow(cat,vmin=0,vmax=np.max(vis.ravel())*0.1,cmap='gray')
    plt.savefig(
        '../PyPRIS_pris'+str(prisN)+'_sat.png',
        dpi=300, figsize=(100, 80))
    plt.close()
    prj0_list.append(prj_ax0)
    prj1_list.append(prj_ax1)
    prj2_list.append(prj_ax2)
    interv_list.append(lb.candidate_intervals)
    print('')
# Out:
# now check pris0
# total number of candidates: 11761
# total number of candidates: 11761
# total number of candidates: 11761
# total number of candidates: 11761
#
# now check pris1
# total number of candidates: 3313
# total number of candidates: 3965
# total number of candidates: 5173
# total number of candidates: 6601
#
# now check pris2
# total number of candidates: 4229
# total number of candidates: 4173
# total number of candidates: 4041
# total number of candidates: 5169
#
# now check pris3
# total number of candidates: 6445
# total number of candidates: 5877
# total number of candidates: 6077
# total number of candidates: 7585
#
# now check pris4
# total number of candidates: 10673
# total number of candidates: 9997
# total number of candidates: 10409
# total number of candidates: 12825
#
# now check pris5
# total number of candidates: 17613
# total number of candidates: 16661
# total number of candidates: 17701
# total number of candidates: 22881
#
# now check pris6
# total number of candidates: 30677
# total number of candidates: 27801
# total number of candidates: 30133
# total number of candidates: 39449
#
# now check pris7
# total number of candidates: 52861
# total number of candidates: 49629
# total number of candidates: 54101
# total number of candidates: 67465

# %%
print(len(prj0_list),len(prj1_list),len(prj2_list),len(interv_list))
# Out:
# 8 8 8 8

# %%
prj0_list[0].shape
# Out:
# (30, 36)

# %%
interv_list
# Out:
# [[1, 6, 6],
#  [1.0, 3.0, 3.0],
#  [1.0, 1.5, 1.5],
#  [1.0, 0.75, 0.75],
#  [1.0, 0.375, 0.375],
#  [1.0, 0.1875, 0.1875],
#  [1.0, 0.09375, 0.09375],
#  [1.0, 0.046875, 0.046875]]

# %% [markdown]
# ## produce figure for pris4

# %%
xcounts = np.int(np.round((1237-1063)*psize/25*10))
print('if resize the x dimension into the size of '+str(xcounts)+'then one pixel along x dimension is 2.5 nm')
print('a 800 nm scale bar would be ' + str(800/2.5) + 'counts of the resized pixels')
# Out:
# if resize the x dimension into the size of 4368then one pixel along x dimension is 2.5 nm
# a 800 nm scale bar would be 320.0counts of the resized pixels

# %%
ycounts = np.int(np.round((1504-1294)*psize/25*10))
print('if resize the y dimension into the size of '+str(ycounts)+'then one pixel along y dimension is 2.5 nm')
print('a 800 nm scale bar would be ' + str(800/2.5) + 'counts of the resized pixels')
# Out:
# if resize the y dimension into the size of 5272then one pixel along y dimension is 2.5 nm
# a 800 nm scale bar would be 320.0counts of the resized pixels

# %%
import scipy
from scipy import misc
prj0 = copy.deepcopy(prj0_list[5])
prj1 = copy.deepcopy(prj1_list[5])
prj2 = copy.deepcopy(prj2_list[5])
pcountsInt = 320
plt.figure(figsize=(15,5))

pj = scipy.misc.imresize(prj0,(xcounts,ycounts),'nearest')
xsta = np.int(pj.shape[0]*0.9)
xend = np.int(pj.shape[0]*0.94)
ysta = np.int(pj.shape[1]*0.9-pcountsInt)
pj[xsta:xend, ysta:ysta+pcountsInt]=np.max(pj.ravel())
plt.subplot(131)
plt.imshow(pj,cmap='bone')

pj = scipy.misc.imresize(prj1,(91*10,ycounts),'nearest')
xsta = np.int(pj.shape[0]*0.9)
xend = np.int(pj.shape[0]*0.94)
ysta = np.int(pj.shape[1]*0.9-pcountsInt)
pj[xsta:xend, ysta:ysta+pcountsInt]=np.max(pj.ravel())
plt.subplot(132)
plt.imshow(pj,cmap='magma')

pj = scipy.misc.imresize(prj2,(xcounts,91*10),'nearest')
xsta = np.int(pj.shape[0]*0.9)
xend = np.int(pj.shape[0]*0.94)
ysta = np.int(pj.shape[1]*0.9-pcountsInt)
pj[xsta:xend, ysta:ysta+pcountsInt]=np.max(pj.ravel())
plt.subplot(133)
plt.imshow(pj,cmap='magma')
# Out:
# C:\Users\xiyu\Anaconda3\envs\PyPRIS_env\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   if __name__ == '__main__':
# C:\Users\xiyu\Anaconda3\envs\PyPRIS_env\lib\site-packages\ipykernel_launcher.py:17: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# C:\Users\xiyu\Anaconda3\envs\PyPRIS_env\lib\site-packages\ipykernel_launcher.py:25: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
# produce a scale bar of 800 nm in xy
tuneF = 0.7
tuneF_botom_raise = -0.01
xthick=50
for prj0, prj1, prj2, prisN in zip(prj0_list, prj1_list, prj2_list, np.arange(0,8)):
    print(prisN)
    pcountsInt = 320
    plt.figure(figsize=(15,5))

    pj = scipy.misc.imresize(prj0,(xcounts,ycounts),'nearest')
    xsta = -200
    ysta = np.int(pj.shape[1]*0.9-pcountsInt)
    pj[xsta:xsta+xthick, ysta:ysta+pcountsInt]=np.max(pj.ravel())
    plt.subplot(131)
    plt.imshow(pj,cmap='gray',vmin=np.max(pj.ravel())*tuneF_botom_raise,vmax=np.max(pj.ravel())*tuneF)
    plt.title('pris'+str(prisN)+'   XY plane')
    plt.axis('off')

    pj = scipy.misc.imresize(prj1,(73*10,ycounts),'nearest')
    xsta = -200
    ysta = np.int(pj.shape[1]*0.9-pcountsInt)
    pj[xsta:xsta+xthick, ysta:ysta+pcountsInt]=np.max(pj.ravel())
    plt.subplot(132)
    plt.imshow(pj,cmap='gray',vmin=np.max(pj.ravel())*tuneF_botom_raise,vmax=np.max(pj.ravel())*tuneF)
    plt.title('pris'+str(prisN)+'   XZ plane')
    plt.axis('off')

    pj = scipy.misc.imresize(prj2,(xcounts,73*10),'nearest')
    xsta = -200
    ysta = np.int(pj.shape[1]*0.9-pcountsInt)
    pj[xsta:xsta+xthick, ysta:ysta+pcountsInt]=np.max(pj.ravel())
    plt.subplot(133)
    plt.imshow(pj,cmap='gray',vmin=np.max(pj.ravel())*tuneF_botom_raise,vmax=np.max(pj.ravel())*tuneF)
    plt.title('pris'+str(prisN)+'   YZ plane')
    plt.axis('off')
# With the pcounts defined above, 340 pixels will always yield a scale bar of 800 nm.
# Out:
# 0
# C:\Users\xiyu\Anaconda3\envs\PyPRIS_env\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\xiyu\Anaconda3\envs\PyPRIS_env\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# C:\Users\xiyu\Anaconda3\envs\PyPRIS_env\lib\site-packages\ipykernel_launcher.py:28: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
plt.imshow(pj,cmap='gray')

# %%
tuneF = 0.7
tuneF_botom_raise = -0.01
xthick=50
prj0 = prj0_list[4] 
prj1 = prj1_list[4] 
prj2 = prj2_list[4] 
prisN = 4
pcountsInt = 320


pj = scipy.misc.imresize(prj0,(xcounts,ycounts),'nearest')
xsta = -200
ysta = np.int(pj.shape[1]*0.9-pcountsInt)
pj[xsta:xsta+xthick, ysta:ysta+pcountsInt]=np.max(pj.ravel())
plt.figure(figsize=(14,14))
plt.imshow(pj,cmap='gray',vmin=np.max(pj.ravel())*tuneF_botom_raise,vmax=np.max(pj.ravel())*tuneF)
plt.title('pris'+str(prisN)+'   XY plane')
plt.axis('off')
scipy.misc.imsave("../prj0.png",pj,format='png')

pj = scipy.misc.imresize(prj1,(73*10,ycounts),'nearest') # stretch by 1.5 fold in the z-direction for better visualization
xsta = -200
ysta = np.int(pj.shape[1]*0.9-pcountsInt)
pj[xsta:xsta+xthick, ysta:ysta+pcountsInt]=np.max(pj.ravel())
plt.figure(figsize=(14,14))
plt.imshow(pj,cmap='gray',vmin=np.max(pj.ravel())*tuneF_botom_raise,vmax=np.max(pj.ravel())*tuneF)
plt.title('pris'+str(prisN)+'   XZ plane')
plt.axis('off')
scipy.misc.imsave("../prj1.png",pj,format='png')

pj = scipy.misc.imresize(prj2,(xcounts,73*10),'nearest')# stretch by 1.5 fold in the z-direction for better visualization
xsta = -200
ysta = np.int(pj.shape[1]*0.9-pcountsInt)
pj[xsta:xsta+xthick, ysta:ysta+pcountsInt]=np.max(pj.ravel())
plt.figure(figsize=(14,14))
plt.imshow(pj,cmap='gray',vmin=np.max(pj.ravel())*tuneF_botom_raise,vmax=np.max(pj.ravel())*tuneF)
plt.title('pris'+str(prisN)+'   YZ plane')
plt.axis('off')
scipy.misc.imsave("../prj2.png",pj,format='png')
# Out:
# C:\Users\xiyu\Anaconda3\envs\PyPRIS_env\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\xiyu\Anaconda3\envs\PyPRIS_env\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# C:\Users\xiyu\Anaconda3\envs\PyPRIS_env\lib\site-packages\ipykernel_launcher.py:21: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# C:\Users\xiyu\Anaconda3\envs\PyPRIS_env\lib\site-packages\ipykernel_launcher.py:29: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# C:\Users\xiyu\Anaconda3\envs\PyPRIS_env\lib\site-packages\ipykernel_launcher.py:31: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# C:\Users\xiyu\Anaconda3\envs\PyPRIS_env\lib\site-packages\ipykernel_launcher.py:39: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.

# %%
maxvis = np.max(vis.ravel())

# %%
for i in np.arange(0,73):
    im = vis[i,:,:]/maxvis*255
    print('z layer '+str(i))
    scipy.misc.imsave("../visualization_pris4_Z"+str(i)+".png",im.astype(np.uint8),format='png')
# Out:
# z layer 0
# C:\Users\xiyu\Anaconda3\envs\PyPRIS_env\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   after removing the cwd from sys.path.
# z layer 1
# z layer 2
# z layer 3
# z layer 4
# z layer 5
# z layer 6
# z layer 7
# z layer 8
# z layer 9
# z layer 10
# z layer 11
# z layer 12
# z layer 13
# z layer 14
# z layer 15
# z layer 16
# z layer 17
# z layer 18
# z layer 19
# z layer 20
# z layer 21
# z layer 22
# z layer 23
# z layer 24
# z layer 25
# z layer 26
# z layer 27
# z layer 28
# z layer 29
# z layer 30
# z layer 31
# z layer 32
# z layer 33
# z layer 34
# z layer 35
# z layer 36
# z layer 37
# z layer 38
# z layer 39
# z layer 40
# z layer 41
# z layer 42
# z layer 43
# z layer 44
# z layer 45
# z layer 46
# z layer 47
# z layer 48
# z layer 49
# z layer 50
# z layer 51
# z layer 52
# z layer 53
# z layer 54
# z layer 55
# z layer 56
# z layer 57
# z layer 58
# z layer 59
# z layer 60
# z layer 61
# z layer 62
# z layer 63
# z layer 64
# z layer 65
# z layer 66
# z layer 67
# z layer 68
# z layer 69
# z layer 70
# z layer 71
# z layer 72

# %%
73*25
# Out:
# 1825
