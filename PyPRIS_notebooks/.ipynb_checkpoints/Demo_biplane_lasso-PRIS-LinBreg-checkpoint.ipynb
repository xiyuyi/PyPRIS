# %%
# import all modules
import numpy as np
import PIL.Image as Image
import libtiff
import matplotlib
from matplotlib import pyplot as plt
import matplotlib
from skimage import io
from PRIS import * 
#import SingleObs
#from PRIS import PyPRIS
#from PRIS import L
import copy
import drawnow

# %load_ext autoreload
# %autoreload 2

# %%
# %reload_ext autoreload

# %% [markdown]
# # Construct obseration operator

# %%
# construct observation operator.
 # load psf matrix
dpath = './test_data/psf.tif';
psf = io.imread(dpath)

# %% [markdown]
# # Load observation

# %%
# load observation
data_path = './test_data';
f = 'obsStack.tif';
fov = io.imread(data_path + '/' + f)
fov.shape
plt.figure(figsize=(5,5));
plt.subplot(131)
plt.imshow(fov[[1,3,5,6,10,15],:,:].reshape(6*fov.shape[1],fov.shape[2]))
blur1 = fov[1,:,:];
blur2 = fov[3,:,:];
#100 nm step interval so there is a 200 nm separation. 8 layer separation between psf steps.

blur = np.concatenate([blur1, blur2]).reshape(2*71,71);
plt.subplot(132)
plt.imshow(blur)

# %% [markdown]
# # Decide candidates

# %%
# decide candidates 
range_ind0 = np.arange(-36,36)
range_ind1 = np.arange(10,66,4)
range_ind2 = np.arange(8,62,4)
candidate_locs = list()
for i0 in range_ind0:
    for i1 in range_ind1:
        for i2 in range_ind2:
            candidate_locs.append([i0,i1,i2])

# %% [markdown]
# # Construct sensing matrix

# %%
# construct sensing matrix
    # dependencies: candidates, observation operator.
    # yield: sensing matrix
    # method: loop over all candidates and record the corresponding observations.
a = SingleObs()
a.psf = np.copy(psf)
a.psfz0 = 106
a.debug = False
a.imsize = blur1.shape
a.edge_padding = True
A = np.ndarray([blur.shape[0]*blur.shape[1], len(candidate_locs)+1])
A.shape
for count, loc in enumerate(candidate_locs):
#for count, loc in enumerate([[0,10,10],[10,10,10]]):
    
    loc1 = np.copy(loc); loc1[0] = np.copy(loc[0])-4
    loc2 = np.copy(loc); loc2[0] = np.copy(loc[0])+4
    a.location = loc1
    a.single_obs()
    a1 = a.obs.ravel()
    
    a.location = loc2
    a.single_obs()
    a2 = a.obs.ravel()
    
    A[:,count] = np.concatenate([a1.ravel(),a2.ravel()]).ravel()
A[:,len(candidate_locs)] = 1

# %% [markdown]
# # Recovery

# %%
# %reload_ext autoreload

# %%
# recover
    # input sensint matrix, and observation; 
    # yield: recovered vector
    # use scikit learn lasso solver
import time
A[:,len(candidate_locs)] = 580
Anorm = A/500
a = LinBreg(Anorm,np.zeros(A.shape[1]),blur.ravel())
a.debug = True
a.deep_debug = False
a.mu = 1000000000
a.obs_dim0 = blur.shape[0]
a.obs_dim1 = blur.shape[1]

#a.stepsize = 1e-6
a.alpha = 1e-8
a.maxit = 6000 # maximum iteration steps.
a.debug_it_int = 1000
a.it_check_rem = 1
a.kick.ints = 10
a.kick.flag = True
a.kick.thres = 1e-3
a.range_ind0 = range_ind0
a.range_ind1 = range_ind1
a.range_ind2 = range_ind2

a.getready()
a.go()
# Out:
# Successfully created the directory ../../PyPRIS_Scratch
# Successfully created the directory ../../PyPRIS_Scratch/debug_output
# Successfully created the directory ../../PyPRIS_Scratch/saved_objects
# G:\DH_localization\test\PyPRIS\PyPRIS_notebooks\PRIS.py:440: RuntimeWarning: divide by zero encountered in double_scalars
#   self.hist_resDrop.append((self.hist_res[it_count] - self.hist_res[it_count-1])/self.hist_res[it_count-1])
# intermediate output it#1
# G:\DH_localization\test\PyPRIS\PyPRIS_notebooks\PRIS.py:410: RuntimeWarning: divide by zero encountered in log
#   plt.plot(self.iterations, np.log(self.hist_res), '.')

# %% [markdown]
# ### Load Previous Linbreg

# %%
a_rec = loadPyPRIS(101)

# %%
plt.imshow(np.mean(a_rec.x[0:a_rec.x.size-1].reshape(a_rec.range_ind0.size,a_rec.range_ind1.size,a_rec.range_ind2.size),axis=0))

# %%
len(a.kick.hist_eval_counts)

# %%
a.kick.hist_eval_counts
plt.scatter(a.kick.hist_eval_counts[0],a.kick.hist_eval_counts[1])

# %%
l=a.hist_kicking_eval_counts

# %%
z = list(zip(*l))
x = list(z[0])
y = list(z[1])

# %%
plt.scatter(x[np.where(y == True)],y[np.where(y == True)], c = z[1])
